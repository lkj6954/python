# %%
# 형태분석된 데이터 로딩
def read_data(filename, encoding='cp949'):               # 읽기 함수 정의
  with open(filename, 'r', encoding=encoding) as f:
    data = [line.split('\t') for line in f.read().splitlines()]
    data = data[1:]                                      # txt 파일의 헤더(id document label)는 제외하기
  return data

def write_data(data, filename, encoding='cp949'):        # 쓰기 함수 정의
  with open(filename, 'w', encoding=encoding) as f:
    f.write(data)

data = read_data('C:\\Users\\LeeKyoungJun\\Desktop\\데이터캠퍼스\\pytest_대용량\\ratings.txt', encoding='cp949')

print(len(data))
print(len(data[0])) 
print(data[0])
# Out:
# 200000
# 3
# ['8112052', '어릴때보고 지금다시봐도 재밌어요ㅋㅋ', '1']

# %%
# 훈련데이터와 테스트데이터 분리 (자동)
data_text = [line[1] for line in data]      		# 데이터 본문
data_senti = [line[2] for line in data]     		# 데이터 긍부정 부분

from sklearn.model_selection import train_test_split
# train_test_split가 데이터(feature, label)를 랜덤하게 섞은 뒤, 트레이닝 데이터와 테스트 데이터에 7:3 비율로 넣는다.
train_data_text, test_data_text, train_data_senti, test_data_senti = train_test_split(data_text, data_senti, stratify=data_senti)

# Counter 클래스를 이용해 각 분류가 훈련데이터와 테스트데이터에 같은 비율로 들어갔는지 확인해 본다 
from collections import Counter
train_data_senti_freq = Counter(train_data_senti)
print('train_data_senti_freq:', train_data_senti_freq)

test_data_senti_freq = Counter(test_data_senti)
print('test_data_senti_freq:', test_data_senti_freq)
# Out:
# train_data_senti_freq: Counter({'1': 75000, '0': 75000})
# test_data_senti_freq: Counter({'0': 25000, '1': 25000})

# %%
# 행렬 형태로 변환
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(min_df=5).fit(train_data_text)  # 빈도 5이상의 단어만 대상. 빈도 수가 너무 적으면 판단에 도움이 안됨
X_train = vect.transform(train_data_text)		           # 행렬 생성. train_data_text로 DTM(틀) 만들어야 한다. 테스트용 데이터로 만들면 안됨 !
print("X_train:\n", repr(X_train))			               # 생성된 행렬 개요
# Out:
# X_train:
#  <150000x24121 sparse matrix of type '<class 'numpy.int64'>'
# 	with 734177 stored elements in Compressed Sparse Row format>

# %%
# 행렬 내용 관찰
feature_names = vect.get_feature_names()
print("특성 개수:", len(feature_names))
print("처음 20개 특성:\m", feature_names[:20])
print("3000~5000까지의 특성:\n", feature_names[3000:5000])
# Out:
# 특성 개수: 24121
# 처음 20개 특성:\m ['007', '007시리즈', '007을', '007의', '007이', '02', '04', '08', '0개', '0개는', '0은', '0점', '0점도', '0점없나', '0점없냐', '0점은', '0점을', '0점이', '0점이다', '0점주고싶다']
# 3000~5000까지의 특성:
#  ['그지같네', '그지같다', '그지같은', '그지같음', '그지없고', '그지없는', '그지없다', '그치만', '그토록', '그후', '극강의', '극과', '극단적', '극단적으로', '극단적인', '극대화', '극도로', '극도의', '극복', '극복하기', '극복하는', '극복할', '극본', '극본과', '극본을', '극악의', '극에', '극으로', '극을', '극의', '극이', '극장', '극장가서', '극장개봉', '극장까지', '극장서', '극장에', '극장에서', '극장에서보고', '극장에서봤는데', '극장에선', '극장용', '극장을', '극장이', '극장판', '극장판도', '극장판으로', '극장판은', '극장판을', '극장판의', '극장판이', '극장판중', '극장판중에', '극적', '극적으로', '극적인', '극전개가', '극중', '극중에서', '극찬', '극찬을', '극치', '극치다', '극치를', '극한', '극한의', '극혐', '극혐이다', '극히', '근거로', '근대', '근데', '근디', '근래', '근래에', '근본적인', '근육', '글고', '글구', '글도', '글렌', '글로', '글로리아', '글쎄', '글쎄다', '글쎄요', '글을', '글이', '글케', '금물', '금발', '금방', '금성무', '금요일', '금요일이', '금치', '급급한', '급의', '급이', '급작스러운', '급전개', '급전개에', '급조한', '급하게', '긋는', '긍정적이고', '긍정적인', '기가', '기가막히게', '기가막히다', '기가막힌', '기간', '기계', '기계가', '기괴하고', '기괴한', '기꺼이', '기냥', '기네스', '기념비적', '기념비적인', '기념으로', '기다려', '기다려져요', '기다려지네요', '기다려지는', '기다려진다', '기다려집니다', '기다렸는데', '기다렸다', '기다렸던', '기다리고', '기다리는', '기다리다', '기다리다가', '기다리며', '기다린', '기다림', '기다립니다', '기대', '기대가', '기대감에', '기대감을', '기대감이', '기대기대', '기대는', '기대도', '기대되고', '기대되네요', '기대되는', '기대되요', '기대된다', '기대됨', '기대됩니다', '기대를', '기대만큼', '기대보다', '기대보단', '기대안하고', '기대안하고봤는데', '기대안했는데', '기대않고', '기대어', '기대없이', '기대에', '기대와', '기대이상', '기대이상으로', '기대이상의', '기대이하', '기대치', '기대치가', '기대하게', '기대하겠습니다', '기대하고', '기대하고봤는데', '기대하는', '기대하며', '기대하면', '기대하면서', '기대하지', '기대하지않고', '기대한', '기대한다', '기대한다면', '기대할게요', '기대할께요', '기대합니다', '기대해', '기대해본다', '기대해봅니다', '기대해서', '기대햇는데', '기대했건만', '기대했는데', '기대했다', '기대했다가', '기대했다면', '기대했던', '기대했던것보다', '기대했었는데', '기대했으나', '기대했지만', '기독교', '기독교는', '기독교를', '기독교인', '기록', '기를', '기막힌', '기묘한', '기반으로', '기발하고', '기발한', '기법', '기법도', '기법이', '기본', '기본도', '기본에', '기본은', '기본이', '기본적으로', '기본적인', '기부를', '기분', '기분나쁜', '기분나쁜영화', '기분나쁨', '기분도', '기분만', '기분으로', '기분은', '기분을', '기분이', '기분이네요', '기분이다', '기분이랄까', '기분이었다', '기분좋게', '기분좋고', '기분좋아지는', '기분좋아지는영화', '기분좋은', '기분좋은영화', '기쁜', '기쁨', '기사', '기사를', '기수', '기술', '기술과', '기술력', '기술력을', '기술은', '기술의', '기술이', '기승전결', '기승전결이', '기어', '기억', '기억과', '기억나', '기억나네', '기억나네요', '기억나는', '기억나는건', '기억나는게', '기억나서', '기억나지', '기억난다', '기억남', '기억남는', '기억도', '기억되는', '기억된다', '기억될', '기억만', '기억상실', '기억속에', '기억속에서', '기억에', '기억에남는', '기억에남는다', '기억에서', '기억으로', '기억은', '기억을', '기억의', '기억이', '기억하게', '기억하고', '기억하는', '기억하는데', '기억하며', '기억한다', '기억할', '기억함', '기억합니다', '기억해야', '기운이', '기원', '기이한', '기자', '기자는', '기자도', '기자들', '기적', '기적같은', '기적을', '기적의', '기적이', '기적이다', '기점으로', '기존', '기존에', '기존의', '기준', '기준에', '기준으로', '기준은', '기준이', '기차', '기타', '기타노', '기타등등', '기회', '기회가', '기회는', '기회를', '기회에', '기획', '긴말', '긴박감', '긴박감이', '긴박하고', '긴박한', '긴장', '긴장감', '긴장감과', '긴장감도', '긴장감도없고', '긴장감없는', '긴장감에', '긴장감은', '긴장감을', '긴장감이', '긴장감이나', '긴장감있게', '긴장감있고', '긴장감있는', '긴장감제로', '긴장과', '긴장도', '긴장되고', '긴장되는', '긴장을', '긴장의', '긴장하게', '긴장하고', '긴장하면서', '길거리', '길게', '길고', '길다', '길들여', '길어', '길어서', '길었다', '길었으면', '길에', '길예르모', '길은', '길을', '길이', '길이길이', '길이남을', '길지', '길지만', '김갑수', '김강우', '김고은', '김구라', '김구라씨', '김규리', '김기덕', '김기덕은', '김기덕의', '김기덕이', '김남길', '김대중', '김대희', '김동완', '김동욱', '김두영', '김래원', '김명민', '김명민의', '김명민이', '김민정', '김민종', '김민준', '김민희', '김범', '김보성', '김빠진', '김사랑', '김선아', '김선아는', '김선아의', '김성수', '김소연', '김수로', '김수미', '김수현', '김승우', '김승우는', '김영철', '김옥빈', '김우빈', '김유정', '김윤석', '김윤진', '김인권', '김일성', '김정은', '김정태', '김정화', '김정훈', '김주혁', '김준호', '김지수', '김지운', '김창완', '김청기', '김태우', '김태희', '김태희는', '김하늘', '김하늘이', '김현주', '김현중', '김혜리', '김혜선', '김혜수', '김혜수의', '김희선', '김희선은', '김희선의', '깁슨', '깃든', '깊게', '깊고', '깊네요', '깊다', '깊숙히', '깊었다', '깊었던', '깊었습니다', '깊은', '깊이', '깊이가', '깊이도', '깊이를', '깊이와', '깊이있게', '깊이있는', '까고', '까놓고', '까는', '까대는', '까먹고', '까메오', '까야', '까지', '까지는', '까지도', '까진', '깍는다', '깍아', '깎는다', '깎아내리는', '깎음', '깎자', '깔고', '깔끔하게', '깔끔하고', '깔끔하다', '깔끔한', '깜놀', '깜짝', '깜짝깜짝', '깜짝놀랐다', '깜짝놀랬다', '깜찍한', '깡패', '깡패영화', '깨고', '깨끗하게', '깨끗하고', '깨끗한', '깨는', '깨닫게', '깨닫고', '깨닫는', '깨달았다', '깨달은', '깨달음', '깨달음과', '깨달음을', '깨달음이', '깨알', '깨알같은', '깨알같이', '깬다', '깼다', '꺄악', '꺼내', '꺼버렸다', '꺼버렸음', '꺼버리고', '꺼버린', '꺼버림', '꺼이꺼이', '꺼져', '꺼져라', '껏다', '껐다', '껐습니다', '껐음', '꼬띠아르', '꼬라지', '꼬리를', '꼬마', '꼬마가', '꼬맹이', '꼬맹이가', '꼬박꼬박', '꼬여서', ' ...

# %%
# 머신러닝 알고리즘 적용
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression # 상대평가 위함
y_train = pd.Series(train_data_senti)	# 리스트 형태를 종속변수가 될 수 있는 1차원 배열(Series)로 만든다. 이건 개발자가 정해놓은 Rule

lr = LogisticRegression(solver="liblinear")
lr.fit(X_train, y_train)  # (본문, 정답)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# 테스트 데이터 입력
X_test = vect.transform(test_data_text) # 트레이닝 데이터로 만든 df에 테스트 데이터 넣음
y_test = pd.Series(test_data_senti)

print("테스트 데이터 점수:", lr.score(X_test, y_test)) # 데이터가 500개밖에 안되는 ratings_morphed 로 하니 57% 나옴
# Out:
# 테스트 데이터 점수: 0.8075

# %%
# 형태소분석기 시작
import rhinoMorph
rn = rhinoMorph.startRhino()

# 형태소 분석
new_input = '그지같다'
inputdata = []
morphed_input = rhinoMorph.onlyMorph_list(rn, new_input, pos=['NNG', 'NNP', 'VV', 'VA', 'XR', 'IC', 'MM', 'MAG', 'MAJ'])
morphed_input = ' '.join(morphed_input) # ['오늘', '정말', '재미있', '하루＇]를 한 개 문자열로 변환

inputdata.append(morphed_input)         # 분석 결과를 리스트로 만들기
print('input data:', inputdata)         # ['오늘 정말 재미있 하루']
# Out:
# filepath:  C:\Anaconda3\lib\site-packages
# classpath:  C:\Anaconda3\lib\site-packages\rhinoMorph/lib/rhino.jar
# JVM is already started~
# RHINO started!
# input data: ['그지 같']

# %%
X_input = vect.transform(inputdata)	    # 앞에서 만든 11445 컬럼의 행렬에 적용
result = lr.predict(X_input) 	          # 0은 부정,1은 긍정

if result == "0":
  print("부정적인 글입니다")
else:
  print("긍정적인 글입니다")
# Out:
# 부정적인 글입니다
