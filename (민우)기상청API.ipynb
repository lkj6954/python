# %%
import json
import requests
from datetime import datetime 
from urllib.request import urlopen

# %%
import datetime

vilage_weather_url = "http://apis.data.go.kr/1360000/VilageFcstInfoService/getVilageFcst?"

service_key="O2uBWXHfhULq2UxXjvMBAnelk6xV6KX%2BwCql93V4uI5vWB7a2VW8sFUyB36iZMkEiDn59HzDfOKvjaVqtNfz0g%3D%3D"

today=datetime.datetime.today()
base_date = today.strftime("%Y%m%d")
base_time = "0800"

nx="60"
ny="128"

payload = "servicekey="+service_key+"&"+\
    "dataType=json"+"&"+\
    "base_date="+base_date+"&"+\
    "base_time="+base_time+"&"+\
    "nx="+nx+"&"+\
    "ny="+ny

res = requests.get(vilage_weather_url+payload)

res.json().get('response').get('body').get('items')
# Out:
# {'item': [{'baseDate': '20200820',
#    'baseTime': '0800',
#    'category': 'POP',
#    'fcstDate': '20200820',
#    'fcstTime': '1200',
#    'fcstValue': '20',
#    'nx': 60,
#    'ny': 128},
#   {'baseDate': '20200820',
#    'baseTime': '0800',
#    'category': 'PTY',
#    'fcstDate': '20200820',
#    'fcstTime': '1200',
#    'fcstValue': '0',
#    'nx': 60,
#    'ny': 128},
#   {'baseDate': '20200820',
#    'baseTime': '0800',
#    'category': 'R06',
#    'fcstDate': '20200820',
#    'fcstTime': '1200',
#    'fcstValue': '0',
#    'nx': 60,
#    'ny': 128},
#   {'baseDate': '20200820',
#    'baseTime': '0800',
#    'category': 'REH',
#    'fcstDate': '20200820',
#    'fcstTime': '1200',
#    'fcstValue': '70',
#    'nx': 60,
#    'ny': 128},
#   {'baseDate': '20200820',
#    'baseTime': '0800',
#    'category': 'S06',
#    'fcstDate': '20200820',
#    'fcstTime': '1200',
#    'fcstValue': '0',
#    'nx': 60,
#    'ny': 128},
#   {'baseDate': '20200820',
#    'baseTime': '0800',
# ...

# %%
def get_sky_info(data):
    try:
        weather_info = data['response']['body']['items']['item']
        if weather_info[3]['category']=='SKY':
            return weather_info[3]['fcstValue']
        elif weather_info[5]['category']=='SKY':
            return weather_info[5]['fcstValue']
    except KeyError:
        print('API 호출 실패!')
        
def get_base_time(hour):
    hour = int(hour)
    if hour<3:
        temp_hour = '20'
    elif hour<6:
        temp_hour = '23'
    elif hour<9:
        temp_hour = '02'
    elif hour<12:
        temp_hour = '05'
    elif hour<15:
        temp_hour = '08'
    elif hour<18:
        temp_hour = '11'
    elif hour<21:
        temp_hour = '14'
    elif hour<24:
        temp_hour = '17'
    
    return temp_hour + '00'

def get_weather():
    service_key = 'O2uBWXHfhULq2UxXjvMBAnelk6xV6KX%2BwCql93V4uI5vWB7a2VW8sFUyB36iZMkEiDn59HzDfOKvjaVqtNfz0g%3D%3D'
    now = datetime.now()
    now_date = now.strftime('%Y%m%d')
    now_hour = int(now.strftime('%H'))
    
    if now_hour<6:
        base_date = str(int(now_dates)-1)
    else:
        base_date = now_date
    base_hour = get_base_time(now_hour)
    
    num_of_rows = '6'
    base_date = base_date
    base_time = base_hour
    nx=str(60)
    ny=str(125)
    _type = 'json'
    api_url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService/getVilageFcst?serviceKey={0}&pageNo={1}&numOfRows={2}&dataType={3}&base_date={4}&base_time={5}&nx={6}&ny={7}&'.format( 
        service_key,1,'10','XML',base_date,base_time,nx,ny)
    
    data = urlopen(api_url).read().decode('utf8')
    json_data = json.loads(data)
    sky=get_sky_info(json_data)
    return sky

weather = get_weather()
print(weather)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-f71eb4d436d5> in <module>
#      56     return sky
#      57
# ---> 58 weather = get_weather()
#      59 print(weather)
#
# <ipython-input-10-f71eb4d436d5> in get_weather()
#      52
#      53     data = urlopen(api_url).read().decode('utf8')
# ---> 54     json_data = json.loads(data)
#      55     sky=get_sky_info(json_data)
#      56     return sky
#
# C:\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ...

# %%
{'item': [{'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'POP',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '0',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'PTY',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '0',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'REH',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '85',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'SKY',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '1',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'T3H',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '24',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'UUU',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '0.3',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'VEC',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '193',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'VVV',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '1.3',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'WSD',
   'fcstDate': '20200820',
   'fcstTime': '0900',
   'fcstValue': '1.3',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0500',
   'category': 'POP',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '20',
   'nx': 60,
   'ny': 128}]}

#####################################3
{'item': [{'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'POP',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '20',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'PTY',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '0',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'R06',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '0',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'REH',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '70',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'S06',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '0',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'SKY',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '3',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'T3H',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '27',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'UUU',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '0.8',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'VEC',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '208',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '0800',
   'category': 'VVV',
   'fcstDate': '20200820',
   'fcstTime': '1200',
   'fcstValue': '1.5',
   'nx': 60,
   'ny': 128}]}
########################################

{'item': [{'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'POP',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '0',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'PTY',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '0',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'REH',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '65',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'SKY',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '1',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'T3H',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '30',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'TMX',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '30.0',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'UUU',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '1.5',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'VEC',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '229',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'VVV',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '1.3',
   'nx': 60,
   'ny': 128},
  {'baseDate': '20200820',
   'baseTime': '1100',
   'category': 'WSD',
   'fcstDate': '20200820',
   'fcstTime': '1500',
   'fcstValue': '2',
   'nx': 60,
   'ny': 128}]}
